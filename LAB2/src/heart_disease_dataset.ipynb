# %% [markdown]
# # Heart Disease Data Exploration
# This notebook loads the Heart Disease UCI dataset and performs basic data inspection.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 1. Load the Dataset

# %%
df = pd.read_csv('heart_disease_uci.csv')
print("Dataset loaded successfully.")

# %% [markdown]
# ### 2. Display Shape

# %%
print(f"The dataset has {df.shape[0]} rows and {df.shape[1]} columns.")
df.shape

# %% [markdown]
# ### 3. Preview First Few Rows

# %%
df.head()

# %% [markdown]
# ### 4. Check Column Names and Data Types

# %%
df.info()
